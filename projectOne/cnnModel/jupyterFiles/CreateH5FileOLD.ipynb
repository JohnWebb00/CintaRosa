# %%
"""
Authors:
- bardiaf - ??
- ...

Usage: None
"""

import keras
import os
import cv2
import imghdr
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_directory = 'C:/users/georg/Downloads/data/data'
image_exist = ['jpeg', 'jpg', 'png']
data = tf.keras.utils.image_dataset_from_directory('C:/users/georg/Downloads/data/data')

malignantcsv = 'C:/users/georg/Downloads/malignant.csv'
benigncsv = 'C:/users/georg/Downloads/benign.csv'
normalcsv = 'C:/users/georg/Downloads/normal.csv'


data_iterator = data.as_numpy_iterator()

batch = data_iterator.next()
data = data.map(lambda x, y: (x / 255, y))


train_size = int(len(data) * .7)
validation_size = int(len(data) * .2) + 1
test_size = int(len(data) * .1) + 1


train_data = data.take(train_size)
validation_data = data.skip(train_size).take(validation_size)
test_data = data.skip(train_size + validation_size).take(test_size)

model = Sequential()

model.add(Conv2D(16, (3, 3), 1, activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(32, (3, 3), 1, activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), 1, activation='relu'))
model.add(MaxPooling2D((2, 2)))


model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  # Dropout layer
model.add(Dense(3, activation='softmax'))  # Output layer with 3 neurons (0, 1, 2)

    
model.compile(optimizer=keras.optimizers.Adam(0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])


log_directory = 'C:/users/georg/Downloads/logs'

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_directory)

history = model.fit(train_data, epochs=50, batch_size=100, validation_data=validation_data, callbacks=[tensorboard_callback])
model.save('C:/users/georg/Downloads/breastCancerModel_v1.h5')

# image = cv2.imread('/Users/bardiaforooraghi/Downloads/Dataset_BUSI_with_GT/malignant/malignant (1).png')

# # Convert the image to grayscale
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# # Apply thresholding to create a binary mask
# _, binary_mask = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

# # Invert the binary mask
# binary_mask = cv2.bitwise_not(binary_mask)

# # Plot the original image
# plt.subplot(1, 2, 1)
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# plt.title('Original Image')
# plt.axis('off')

# # Plot the inverted binary mask
# plt.subplot(1, 2, 2)
# plt.imshow(binary_mask, cmap='gray')
# plt.title('Inverted Binary Mask')
# plt.axis('off')

# # Display the plots
# plt.show()
# Out:
# Found 588 files belonging to 3 classes.
# Epoch 1/50
# 13/13 [==============================] - 11s 106ms/step - loss: 0.7799 - accuracy: 0.6130 - val_loss: 0.6071 - val_accuracy: 0.6875
# Epoch 2/50
# 13/13 [==============================] - 1s 90ms/step - loss: 0.5576 - accuracy: 0.7212 - val_loss: 0.4068 - val_accuracy: 0.8750
# Epoch 3/50
# 13/13 [==============================] - 1s 91ms/step - loss: 0.4143 - accuracy: 0.8558 - val_loss: 0.2605 - val_accuracy: 0.9297
# Epoch 4/50
# 13/13 [==============================] - 1s 89ms/step - loss: 0.2934 - accuracy: 0.8870 - val_loss: 0.2410 - val_accuracy: 0.9062
# Epoch 5/50
# 13/13 [==============================] - 1s 91ms/step - loss: 0.2106 - accuracy: 0.9207 - val_loss: 0.1425 - val_accuracy: 0.9609
# Epoch 6/50
# 13/13 [==============================] - 1s 91ms/step - loss: 0.1485 - accuracy: 0.9447 - val_loss: 0.1316 - val_accuracy: 0.9609
# Epoch 7/50
# 13/13 [==============================] - 1s 91ms/step - loss: 0.1206 - accuracy: 0.9688 - val_loss: 0.0852 - val_accuracy: 0.9766
# Epoch 8/50
# 13/13 [==============================] - 1s 95ms/step - loss: 0.0898 - accuracy: 0.9688 - val_loss: 0.0433 - val_accuracy: 0.9844
# Epoch 9/50
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0832 - accuracy: 0.9736 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 10/50
# 13/13 [==============================] - 1s 88ms/step - loss: 0.0782 - accuracy: 0.9760 - val_loss: 0.0473 - val_accuracy: 0.9766
# Epoch 11/50
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0598 - accuracy: 0.9832 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 12/50
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0362 - accuracy: 0.9928 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch